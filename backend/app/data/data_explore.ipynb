# %%
import pandas as pd

# %%
df = pd.read_csv("brfss2023_diabetes_cleaned.csv")

# %%
df['age_group'].value_counts(normalize=True) * 100
# Out:
# age_group
# 6    38.067446
# 5    17.986121
# 4    14.272956
# 3    12.975079
# 2    10.633407
# 1     6.064991
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#    id  age_group  sex  race  education  bmi_category  physical_activity  \
# 0   0          6    1     1          3             4                  0
# 1   1          6    1     1          3             3                  1
# 2   2          6    1     2          2             2                  1
# 3   3          6    1     1          3             3                  1
# 4   4          6    1     1          3             3                  1
#
#    alcohol_consumption_cat  smoking_status  high_blood_pressure  \
# 0                        0               0                    1
# 1                        0               0                    1
# 2                        0               0                    1
# 3                        0               0                    0
# 4                        1               0                    1
#
#    high_cholesterol  heart_disease  kidney_disease  diabetes_status
# 0                 0              0               0                1
# ...
